# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)
points = 500
x = np.linspace(-3, 3, points) # In between we will have 10 points
y = np.sin(x) + np.random.uniform(-0.5, 0.5, points)

plt.scatter(x, y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(x, y, epochs=50)
# Out:
# WARNING:tensorflow:From c:\users\dapplogix\anaconda3\envs\soundclassification\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 500/500 [==============================] - 0s 386us/step - loss: 0.4560
# Epoch 2/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.2402
# Epoch 3/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.2620
# Epoch 4/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.2257
# Epoch 5/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.2283
# Epoch 6/50
# 500/500 [==============================] - 0s 31us/step - loss: 0.2252
# Epoch 7/50
# 500/500 [==============================] - 0s 27us/step - loss: 0.2179
# Epoch 8/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.2204
# Epoch 9/50
# 500/500 [==============================] - 0s 26us/step - loss: 0.2047
# Epoch 10/50
# 500/500 [==============================] - 0s 25us/step - loss: 0.1913
# Epoch 11/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.1914
# Epoch 12/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1781
# Epoch 13/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1688
# Epoch 14/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.1582
# Epoch 15/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1557
# Epoch 16/50
# 500/500 [==============================] - ETA: 0s - loss: 0.142 - 0s 26us/step - loss: 0.1450
# Epoch 17/50
# 500/500 [==============================] - 0s 26us/step - loss: 0.1386
# Epoch 18/50
# 500/500 [==============================] - 0s 24us/step - loss: 0.1311
# Epoch 19/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1222
# Epoch 20/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.1271
# Epoch 21/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1180
# Epoch 22/50
# 500/500 [==============================] - ETA: 0s - loss: 0.111 - 0s 26us/step - loss: 0.1169
# Epoch 23/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1184
# Epoch 24/50
# 500/500 [==============================] - 0s 26us/step - loss: 0.1175
# Epoch 25/50
# 500/500 [==============================] - ETA: 0s - loss: 0.160 - 0s 24us/step - loss: 0.1113
# Epoch 26/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1081
# Epoch 27/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1111
# Epoch 28/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1244
# Epoch 29/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1239
# Epoch 30/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.1129
# Epoch 31/50
# 500/500 [==============================] - 0s 26us/step - loss: 0.1079
# Epoch 32/50
# 500/500 [==============================] - 0s 24us/step - loss: 0.1143
# Epoch 33/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1080
# Epoch 34/50
# 500/500 [==============================] - 0s 32us/step - loss: 0.1112
# Epoch 35/50
# 500/500 [==============================] - 0s 24us/step - loss: 0.1047
# Epoch 36/50
# 500/500 [==============================] - 0s 17us/step - loss: 0.1088
# Epoch 37/50
# 500/500 [==============================] - 0s 18us/step - loss: 0.1069
# Epoch 38/50
# 500/500 [==============================] - 0s 19us/step - loss: 0.1057
# Epoch 39/50
# 500/500 [==============================] - 0s 20us/step - loss: 0.1052
# Epoch 40/50
# 500/500 [==============================] - 0s 18us/step - loss: 0.1048
# Epoch 41/50
# 500/500 [==============================] - 0s 32us/step - loss: 0.1152
# Epoch 42/50
# 500/500 [==============================] - ETA: 0s - loss: 0.122 - 0s 32us/step - loss: 0.1032
# Epoch 43/50
# 500/500 [==============================] - 0s 22us/step - loss: 0.1035
# Epoch 44/50
# 500/500 [==============================] - 0s 26us/step - loss: 0.1060
# Epoch 45/50
# 500/500 [==============================] - 0s 28us/step - loss: 0.1021
# Epoch 46/50
# 500/500 [==============================] - 0s 32us/step - loss: 0.1019
# Epoch 47/50
# 500/500 [==============================] - 0s 32us/step - loss: 0.1124
# Epoch 48/50
# 500/500 [==============================] - 0s 26us/step - loss: 0.1088
# Epoch 49/50
# 500/500 [==============================] - 0s 32us/step - loss: 0.1042
# Epoch 50/50
# 500/500 [==============================] - 0s 30us/step - loss: 0.1079

# %%
predictions = model.predict(x)
plt.scatter(x, y)
plt.plot(x, predictions, 'ro')
plt.show()
